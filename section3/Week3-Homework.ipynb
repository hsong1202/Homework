# %% [markdown]
# # 3.1 Homework
#
# 1. What is an algorithm?
# algorithm is a problem solving mechanism using series of steps
#
# 2. Variable names may not start with certain characters - name two.
# variable names may not start with numbers and special characters other than an underscore character, i.e. !,?
#
# 3. What is a Semantic error?
# Semantic Error is a type of error that generates an outcome other than the expected result.
#
# 4. What is the #1 rule of coding / debugging?
# "complexity is the enemy of efficiency"
#
# 5. List 5 Python reserved words.
# def, if, ifel, else, True, False

# %%
#6 Write a multi-line comment with your name, favorite food, and dream job on 3 different lines
# Habum Song
# Mexican Food
# Astronaut

#7 Assign 5 different data types to 5 different variables. At least one datatype must be a string
a = "this is a string value"
b = 2
c = True
d = 4.1
e = [5, 6, 7, 8, 9]

# Print the length of your string
print(len(a))

# Print the index value of the 4th character in your string
print(a[3:4])

#8 Create a new variable called savvy, and assign it the string with this phrase "Learning Data Analytics and Python is Awesome!"

savvy = "Leanring Data Analytics and Python is Awesome!"
# Return a range of characters that slices the above string from the beginning of "ing" up to before "and"

print(savvy[5:24])

# Replace "Awesome" with "great" in the string
savvy.replace("Awesome", "great")

# Test and print the savvy string to see it contains "Python"
print(savvy)

#9 Create and assign 3 more variables called name, age and length using the multi-variable naming method
name = "habum"
age = 21
length = 6




# Format a new string called 'miniBio' using variables in curly brackets to complete this phrase... "Hi my name is (name), I am (tall) and (so) old today."
miniBio = f"Hi my name is {name}, I am {length}ft tall and {age} old today."


# Print 'miniBio'
print(miniBio)

# Cast and print the age variable to a float
print(float(length))
# Out:
# 22
# s
# ing Data Analytics
# Leanring Data Analytics and Python is Awesome!
# Hi my name is habum, I am 6ft tall and 21 old today.
# 6.0

# %% [markdown]
# # 3.2 Homework

# %%
#10 
newList = [1, "two", [1, 2, 3], True, 5.0]

print("this is a new list", newList)
# Replace a part of it with something else
newList[1] = 2

print("this is a new list with a replaced index of 1", newList)
# Append or insert several more items to the list
newList.append(6)
print("this is a new list with an appended number 6 at the end", newList)
# Find and print the length of the list
listlength = len(newList)

print(f"the lenght of the new list is {listlength} elements long")
# Slice a sub-section of the 1st list, and save it to a different 2nd list
diffList = newList[:3]
# Print the 2nd list

print("this is a different list:", diffList)
# Extend your original list with the 2nd list sliced above
newList = newList + diffList

print("this is a new list with a different list appended at the end:", newList)
# Create a new list called "simList" containing at least 5 elements of the same data type, either string, integer, float, or Boolean

simList = ["uno", "dos", "tres", "quatro", "cinco"]

print("this is a new list called simList:", simList)
# Sort "simList", and print the list
simList.sort()

print("this is a simList sorted:", simList)
# Copy the "simList" list to another 3rd list
thirdList = simList

# Add the 2nd and 3rd lists together into a 4th list
forthList = diffList + thirdList
print("this is a forth list:", forthList)








#11 Create a tuple of about 5 elements
newTuple = (1,2, 3, 4, 5)

# Multiply your tuple by 3 and save it to a new 2nd tuple
secTuple = newTuple * 3

# Access and print the 12th element from the 2nd tuple
print(secTuple[11])

# Sort the 2nd tuple and print it
secTuple = sorted(secTuple)
print(secTuple)

# Copy 4 specific elements from your 2nd tuple to a new 3nd tuple
thirTuple = secTuple[0:4]

# Unpack the 3rd tuple into 4 variables and print these variables
a = thirTuple[0]
b = thirTuple[1]
c = thirTuple[2]
d = thirTuple[3]
print(a, b, c, d)


# Create a 4th tuple with single item 50 and print this tuple
forthTuple = (50,)
print(forthTuple)


# Add the 2nd and 3rd tuple together into a 5th tuple and print the tuple
forthTuple = secTuple + thirTuple
print(forthTuple)


#12. Create a set of about 3 elements

newSet = {"one", "two", "three"}
fruitList = {"apple", "pear", "banana"}
# Add a list of fruits to the above set and print the result
newSet.update(fruitList)
print(newSet)

# Add a car element to your set
carElement = {"hyundai", "toyota", "kia"}
newSet.update(carElement)
print(newSet)

# Create a 2nd set with a few odd items
secSet = {"few", "odd", "items"}
print(secSet)

# Save the union of 1st set and 2nd set to a 3rd set
thirdSet = newSet.union(secSet)
print(thirdSet)

# Pop an element from the 2nd set, and print the remainder of the set
secSet.pop()
print(secSet)

# Clear the 1st set and print the result
newSet.clear()
print(newSet)

# Discard an element, and remove another element from the 3rd set
thirdSet.discard("items")
thirdSet.remove("one")

# Print the remainder of the 3rd set
print(thirdSet)


# 13. Create a dictionary with at least 5 values of different data types
newDict = {'a':1 , 'b':2 , 'c':3, 'd':4, 'e':5}

# Print out 1 value
print(newDict['a'])

# Replace any one value in your dictionary with your name
newDict['a'] = "habum"
print(newDict['a'])

# Add your favorite color to the dictionary
newDict['f'] = "orange"

# Add a list, tuple or set to your dictionary
newDict['g'] = [1, 2, 3, 4]

# Print a list of the dictionary keys
newDict.keys()

# Print a list of the dictionary values
newDict.values()


# Copy your 1st dictionary into a 2nd dictionary
secDict = newDict.copy()

# Pop an item from the 2nd dictionary, and print the dictionary
secDict.popitem()
print(secDict)

# Remove all the elements from the 2nd dictionary and print the result
secDict.clear()
print(secDict)
# Out:
# this is a new list [1, 'two', [1, 2, 3], True, 5.0]
# this is a new list with a replaced index of 1 [1, 2, [1, 2, 3], True, 5.0]
# this is a new list with an appended number 6 at the end [1, 2, [1, 2, 3], True, 5.0, 6]
# the lenght of the new list is 6 elements long
# this is a different list: [1, 2, [1, 2, 3]]
# this is a new list with a different list appended at the end: [1, 2, [1, 2, 3], True, 5.0, 6, 1, 2, [1, 2, 3]]
# this is a new list called simList: ['uno', 'dos', 'tres', 'quatro', 'cinco']
# this is a simList sorted: ['cinco', 'dos', 'quatro', 'tres', 'uno']
# this is a forth list: [1, 2, [1, 2, 3], 'cinco', 'dos', 'quatro', 'tres', 'uno']
# 2
# [1, 1, 1, 2, 2, 2, 3, 3, 3, 4, 4, 4, 5, 5, 5]
# 1 1 1 2
# (50,)
# [1, 1, 1, 2, 2, 2, 3, 3, 3, 4, 4, 4, 5, 5, 5, 1, 1, 1, 2]
# {'pear', 'one', 'banana', 'apple', 'three', 'two'}
# {'pear', 'one', 'banana', 'three', 'kia', 'toyota', 'hyundai', 'apple', 'two'}
# {'items', 'few', 'odd'}
# {'pear', 'one', 'banana', 'items', 'odd', 'three', 'kia', 'toyota', 'hyundai', 'few', 'apple', 'two'}
# {'few', 'odd'}
# set()
# {'pear', 'banana', 'odd', 'three', 'kia', 'toyota', 'hyundai', 'few', 'apple', 'two'}
# 1
# habum
# {'a': 'habum', 'b': 2, 'c': 3, 'd': 4, 'e': 5, 'f': 'orange'}
# {}
